# %% [markdown]
# # PCA

# %% [markdown]
# ## Task 1: Exploratory Data Analysis (EDA):

# %% [markdown]
# ### 1.	Load the dataset and perform basic data exploration.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
df = pd.read_csv('./wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
# Checking for Null Values
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
# Checking for Duplicate Values
df.duplicated().sum()
# Out:
# 0

# %%
# Statistical Summary
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %% [markdown]
# ### 2.	Examine the distribution of features using histograms, box plots, or density plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histograms for each feature
plt.figure(figsize=(12, 10))
for i, col in enumerate(df.columns):
    plt.subplot(5, 5, i+1)
    sns.histplot(df[col], bins=20, kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Checking for Outliers:

plt.figure(figsize=(12, 10))
for i, col in enumerate(df.columns):
    plt.subplot(5, 5, i+1)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Density plots for each feature
plt.figure(figsize=(12, 10))
for i, col in enumerate(df.columns):
    plt.subplot(5, 5, i+1)
    sns.kdeplot(df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.	Investigate correlations between features to understand relationships within the data.

# %%
# Checking Correlations using Pairplot
sns.pairplot(df)

# %%
# Checking Correlations using Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### Findings:
#
# 1. Based on Correlations, 'Type' has moderate correlations with several features, indicating potential predictve power.
# 2. 'Phenol' and 'Flavanoids' exhibit strong negative correlations with 'Type', suggesting they might be important predictors for classification.
# 3. 'Alcohol' has a moderate negative correlation with 'Type', indicating a potential relationship between alcohol content and wine type.
# 4. There are also strong positive correlations between 'Phenols' and 'Flavanoids', 'Alcohol' and 'Proline'.

# %% [markdown]
# ## Task 2: Dimensionality Reduction with PCA:

# %% [markdown]
# ### 1.	Standardize the features to ensure they have a mean of 0 and a standard deviation of Implement PCA to reduce the dimensionality of the dataset.

# %%
# Standardize the features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Implemening PCA
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(scaled_data)
# Out:
# PCA()

# %% [markdown]
# ### 2.	Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.

# %%
# Determining Optimal number of Principal Components
plt.figure(figsize=(10,6))
plt.plot(
    range(1, len(pca.explained_variance_ratio_) + 1), 
    pca.explained_variance_ratio_.cumsum(), 
    marker='o', 
    linestyle='--'
)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# This plot is often referred to as a scree plot. The scree plot helps in determining the number of principal components to retain in order to effectively represent the variability in the original data.
#
# Typically, one looks for the "elbow" or point of diminishing returns in the scree plot, where adding additional components doesn't contribute much to the cumulative explined variance. This point can guide the selection of the optimal number of principal components to retain for dimensionality reduction while still preserving most of the variance in the original data.

# %% [markdown]
# ### 3.	Transform the original dataset into the principal components.

# %%
# Transforming the original dataset into Principal Components
num_components = 3
pca = PCA(n_components= num_components)
pca_data = pca.fit_transform(scaled_data)

# %% [markdown]
# ## Task 3: Clustering with Original Data:

# %% [markdown]
# ### 1.	Apply a clustering algorithm (e.g., K-means) to the original dataset.

# %%
from sklearn.cluster import KMeans

# Applying K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Getting cluster labels
kmeans_labels = kmeans.labels_

# Evaluating K-Means Cluster

# Add K-Means cluster labels to the dataset
dt = df
dt['KMeans_Cluster'] = kmeans_labels

# Analyze the characteristics of each cluster
cluster_analysis = dt.groupby('KMeans_Cluster').mean()

# Interpretation
print("K-Means Cluster Analysis:")
display(cluster_analysis)
# Out:
# K-Means Cluster Analysis:
#                     Type    Alcohol     Malic       Ash  Alcalinity  \
# KMeans_Cluster
# 0               2.000000  12.254118  1.914265  2.239118   20.079412
# 1               1.032787  13.711475  1.997049  2.453770   17.281967
# 2               2.979592  13.151633  3.344490  2.434694   21.438776
#
#                  Magnesium   Phenols  Flavanoids  Nonflavanoids  \
# KMeans_Cluster
# 0                93.044118  2.248971    2.073382       0.362941
# 1               107.786885  2.842131    2.969180       0.289180
# 2                99.020408  1.678163    0.797959       0.450816
#
#                 Proanthocyanins     Color       Hue  Dilution      Proline
# KMeans_Cluster
# 0                      1.601324  3.064706  1.054206  2.788529   506.588235
# 1                      1.922951  5.444590  1.067705  3.154754  1110.639344
# 2                      1.163061  7.343265  0.685918  1.690204   627.551020

# %% [markdown]
# ### 2.	Visualize the clustering results using appropriate plots.

# %%
# Visualizing clustering results
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Dilution', y='Alcohol', hue='KMeans_Cluster', data=dt, palette='Set1', s=100)
plt.title('K-Means Clustering Results')
plt.xlabel('Dilution in Wine')
plt.ylabel('Alcohol Content')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3.	Evaluate the clustering performance using metrics such as silhouette score or Davies–Bouldin index.

# %%
# Evaluating Clustering Performance
from sklearn.metrics import silhouette_score

silhouette_score_original = silhouette_score(scaled_data, kmeans.labels_)
print(f'Silhouette Score for Cluster using Original Data: {silhouette_score_original}')
# Out:
# Silhouette Score for Cluster using Original Data: 0.30773604383565206

# %% [markdown]
# ## Task 4: Clustering with PCA Data:

# %% [markdown]
# ### 1.	Apply the same clustering algorithm to the PCA-transformed dataset.

# %%
# Applying K-Means Clustering on PCA Transformed Data
kmeans_pca = KMeans(n_clusters=3, random_state=42)
kmeans_pca.fit(pca_data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Getting cluster labels
kmeans_pca_labels = kmeans_pca.labels_

# Evaluating K-Means Cluster

# Add K-Means cluster labels to the dataset
dtt = df
dtt['KMeans_Cluster_pca'] = kmeans_pca_labels

# Analyze the characteristics of each cluster
pca_cluster_analysis = dt.groupby('KMeans_Cluster_pca').mean()

# Interpretation
print("K-Means Cluster Analysis:")
display(pca_cluster_analysis)
# Out:
# K-Means Cluster Analysis:
#                         Type    Alcohol     Malic       Ash  Alcalinity  \
# KMeans_Cluster_pca
# 0                   2.979592  13.151633  3.344490  2.434694   21.438776
# 1                   1.048387  13.676774  1.997903  2.466290   17.462903
# 2                   2.000000  12.264478  1.912239  2.224328   19.953731
#
#                      Magnesium   Phenols  Flavanoids  Nonflavanoids  \
# KMeans_Cluster_pca
# 0                    99.020408  1.678163    0.797959       0.450816
# 1                   107.967742  2.847581    3.003226       0.292097
# 2                    92.656716  2.235075    2.028507       0.361343
#
#                     Proanthocyanins     Color       Hue  Dilution  \
# KMeans_Cluster_pca
# 0                          1.163061  7.343265  0.685918  1.690204
# 1                          1.922097  5.453548  1.065484  3.163387
# 2                          1.597313  3.020896  1.056060  2.775075
#
# ...

# %% [markdown]
# ### 2.	Visualize the clustering results obtained from PCA-transformed data.

# %%
# Visualizing clustering results
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Dilution', y='Alcohol', hue='KMeans_Cluster_pca', data=dtt, palette='Set1', s=100)
plt.title('K-Means Clustering Results')
plt.xlabel('Dilution in Wine')
plt.ylabel('Alcohol Content')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
# Evaluating Clustering Performance

silhouette_score_pca = silhouette_score(pca_data, kmeans_pca.labels_)
print(f'Silhouette Score for Cluster using PCA Data: {silhouette_score_pca}')
# Out:
# Silhouette Score for Cluster using PCA Data: 0.48817506649357856

# %% [markdown]
# ### 3.	Compare the clustering results from PCA-transformed data with those from the original dataset.

# %%
# Comparing Results from both the Clusters
print(f'Silhouette Score (with original data): {silhouette_score_original}')
print(f'Silhouette Score (with PCA data): {silhouette_score_pca}')

fig, axs = plt.subplots(1,2, figsize=[15,6])
sns.scatterplot(x='Dilution', y='Alcohol', hue='KMeans_Cluster', data=dt, palette='Set1', s=100, ax=axs[0])
axs[0].set_title('K-Means Cluster using Original Data')
sns.scatterplot(x='Dilution', y='Alcohol', hue='KMeans_Cluster_pca', data=dtt, palette='Set1', s=100, ax=axs[1])
axs[1].set_title('K-Means Cluster using PCA Data')
plt.show()
# Out:
# Silhouette Score (with original data): 0.30773604383565206
# Silhouette Score (with PCA data): 0.48817506649357856

# %% [markdown]
# ## Task 5: Comparison and Analysis:

# %% [markdown]
# ### 1.	Compare the clustering results obtained from the original dataset and PCA-transformed data.
#
# Comparing Clustering Results of Original Data and PCA Data:
#
# * Original Data:
#
#     1. Cluster 0: Characterized by lower 'Alcohol', 'Malic', 'Ash', and 'Magnesium' levels, moderater 'Phenols' and 'Flavanoids', and moderate 'Proline'.
#
#     2. Cluster 1: Exhibits higher 'Alcohol', 'Flavanoids', and 'Proline' levels, moderate 'Phenols', and 'Proanthocyanins', and higer 'Color', 'Hue', and 'Dilution'.
#
#     3. Cluster 2: Shows higher 'Ash', 'Alcalinity', and 'Proanthocyanins', lower 'Phenols' and 'Flavanoids', and moderate 'Color', 'Hue', 'Dilution', and 'Proline'.
#
# * PCA Transformed Data:
#
#     1. Cluster 0: Similar to Cluster 2 in the original data, characterized by higher 'Ash', 'Alcalinity', and 'Proanthocyanins', lower 'Phenols' and 'Flavanoids', and moderate other features.
#
#     2. Cluster 1: Similar to Cluster 1 in the original data, exhibiting higer 'Alcohol', 'Flavanoids', and 'Proline', moderate 'Phenols' and 'Proanthocyanins', and higher 'Color', 'Hue', and 'Dilution'.
#
#     3. Cluster 2: Similar to Cluster 0 in the original data, showing lower 'Alcohol', 'Malic', 'Ash', and 'Magnesium', moderate 'Phenols' and 'Flavanoids', and moderate 'Proline'.

# %% [markdown]
# ### 2.	Discuss any similarities or differences observed in the clustering results.
#
# Similarities between both the Clusters:
#
# * Both clustering results show some consistency in the characteristics of the clusters.
# * Clusters from PCA transformed data exhibit similar trends to those from the original data.
#
# Differences between both the Clusters:
#
# * Some differences in the ordering of the clusters and slight variations in the feature values within each cluster.

# %% [markdown]
# ### 3.	Reflect on the impact of dimensionality reduction on clustering performance.
#
# * PCA reduced the dimensionality of the data while retaining most of the variance.
# * The Silhouette score for the clustering on PCA transformed data (0.488) is higher than that of the original data (0.308), indicating better defined clusters.
# * Dimensionality reduction with PCA helped in capturing the underlying structure of the data more effectively, leading to improved clustering performance.

# %% [markdown]
# ### 4.	Analyze the trade-offs between using PCA and clustering directly on the original dataset.
#
# Trade-offs between PCA and Original Data:
#
# * PCA:
#
#     1. Reduces dimensionality, captures underlying variance, improved clustering performance.
#     2. May lose some interpretability, may not capture all relevant features.
#
# * Original Data:
#
#     1. Preserves original feature space, maintains interpretability.
#     2. High dimensionality, potential noise or irrelevant features.
#
# PCA Transformed data clustering generally outperforms clustering on the original data, as evidenced by the higer Silhouette score. However, the choice between PCA and original data clustering depends on the specific goals of the analysis and the balance between dimensionality reduction and interpretability.

# %% [markdown]
# ## Task 6: Conclusion and Insights

# %% [markdown]
# ### 1.	Summarize the key findings and insights from the assignment.
#
# * Clustering analysis was performed on the dataset using both the original features and features transformed through Principal Component Analysis (PCA).
# * Silhouette scores were used to evaluate the clustering performance.
# * The clustering results revealed distinct clusters in both the original and PCA Transformed data.
# * Comparison of the clustering results showed similarities in cluster characteristics between the original and PCA transformed data, with slight variations.
# * PCA Transformed data clustering generally showed improved clustering performance, as indicated by higer Silhouette scores.

# %% [markdown]
# ### 2.	Discuss the practical implications of using PCA and clustering in data analysis.
#
# Practical Implications of PCA:
#
# * Dimensionality reduction: PCA helps in reducing the number of features while retaining most of the variance in the data.
# * Visualization: PCA facilitates visualization of high-dimensional data in a lower-dimensional space.
# * Noise reduction: PCA can help in filtering out noise and irrelevant features.
#
# Practical Implications fo Clustering:
#
# * Pattern Discovery: Clustering helps in identifying natural groupings or patterns within data.
# * Segmentation: Clustering enables segmentation of data into meaningful groups, which can be useful for targeted marketing or personalized recommendations.
# * Anomaly detection: Clustering can also be used for anomaly detection by identifying data points that do not belong to any cluster.

# %% [markdown]
# ### 3.	Provide recommendations for when to use each technique based on the analysis conducted.
#
# Use PCA when:
# * Dealing with high-dimensional data.
# * Want to reduce computational complexity.
# * Need to visualize data in a lower-dimensional space.
#
# Use Clustering when:
# * Exploring underlying patterns or structures within data.
# * Need to segment data into distinct groups.
# * Want to identify outliers or anomalies within the dataset.
#
# Use PCA followed by Clustering when:
# * Dealing with very high-dimensional data.
# * Want to improve clustering performance by reducting dimensionality and noise.
# * Need both dimensionality reduction and clustering for data analysis.
#
# The Combination of PCA and Clustering can be powerful in extracting meaningful insights from complex datasets, providing a balance between dimensionality reduction, interpretability, and clustering performance. The choice of technique depends on the specific goals of the analysis and the nature of the dataset.
