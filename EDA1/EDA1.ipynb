# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df['LB'].fillna(df['LB'].mean(), inplace=True)
df['AC'].fillna(df['AC'].mean(), inplace=True)
df['DS'].fillna(df['DS'].mean(), inplace=True)
df['DP'].fillna(df['DP'].mean(), inplace=True)
df['MLTV'].fillna(df['MLTV'].mean(), inplace=True)
df['Width'].fillna(df['Width'].mean(), inplace=True)
df['Tendency'].fillna(df['Tendency'].mean(), inplace=True)
df['NSP'].fillna(df['NSP'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
z_scores = np.abs((df - df.mean()) / df.std())
outlier_threshold = 4  # Adjust as needed
#outliers = df[z_scores > outlier_threshold]
df[z_scores > outlier_threshold] = np.nan

# %%
df.isnull().sum()
# Out:
# LB          10
# AC          10
# FM          37
# UC          10
# DL          11
# DS          16
# DP          21
# ASTV        10
# MSTV        14
# ALTV        10
# MLTV        13
# Width       10
# Tendency    10
# NSP          4
# dtype: int64

# %%
df['AC'].fillna(df['AC'].mean(), inplace=True)
df['FM'].fillna(df['FM'].mean(), inplace=True)
df['DL'].fillna(df['DL'].mean(), inplace=True)
df['DS'].fillna(df['DS'].mean(), inplace=True)
df['DP'].fillna(df['DP'].mean(), inplace=True)
df['MSTV'].fillna(df['MSTV'].mean(), inplace=True)
df['ALTV'].fillna(df['ALTV'].mean(), inplace=True)
df['MLTV'].fillna(df['MLTV'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          10
# AC           0
# FM           0
# UC          10
# DL           0
# DS           0
# DP           0
# ASTV        10
# MSTV         0
# ALTV         0
# MLTV         0
# Width       10
# Tendency    10
# NSP          4
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
def iqr(column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    return q3 - q1

# %%
summary = pd.DataFrame(columns=['Columns', 'Mean' ,'Median', 'IQR', 'Variance', 'Skewness', 'Kurtosis'])

for i in df.columns.to_list():
    summary.loc[len(summary)] = [i, round(df[i].mean(), 6), round(df[i].median(), 6), round(iqr(i), 6), round(df[i].var(), 6), round(df[i].skew(), 6), round(df[i].kurt(), 6)]
summary
# Out:
#      Columns        Mean      Median        IQR     Variance  Skewness  \
# 0         LB  133.268648  133.000000  14.000000    95.383307  0.007407
# 1         AC    0.003161    0.001689   0.005510     0.000015  1.222391
# 2         FM    0.004509    0.000000   0.002605     0.000230  7.465119
# 3         UC    0.004355    0.004481   0.004661     0.000009  0.156126
# 4         DL    0.001883    0.000000   0.003245     0.000009  1.706966
# 5         DS    0.000000    0.000000   0.000000     0.000000  0.000000
# 6         DP    0.000135    0.000000   0.000000     0.000000  4.020214
# 7       ASTV   46.984150   49.000000  29.000000   295.768953 -0.012911
# 8       MSTV    1.324512    1.200000   1.000000     0.724571  1.425189
# 9       ALTV    9.861699    0.000000  11.000000   337.925823  2.196818
# 10      MLTV    8.152802    7.500000   6.003295    29.342793  1.071667
# 11     Width   70.329682   68.000000  63.000000  1498.158922  0.315592
# ...

# %% [markdown]
# #### Key Findings:
#
# ##### 1. Baseling Fetal Heart Rate (LB):
#
# * The mean baseline fetal heart rate is approximately 133 beats per minute, with a median of 133 bpm.
# * The interquartile range (IQR) is relatively small at 14 bpm, indicating that most observations cluster around the median.
# * The variance is moderate, suggesting some variability in fetal heart rates across the dataset.
# * The skewness is close to zero, indicating a relatively symmetric distribution.
# * The kurtosis is negative, suggesting a slightly flatter distribution compared to a normal distribution.
#
# ##### 2. Fetal Movement (FM):
#
# * The mean percentage of detected fetal movements is around 0.45%, with a median of 0%.
# * The distriution is highly skewed to the right, indicating that most observations have no fetal movements detected, but a few have a high percentage of movements.
# * The kurtosis is extremely high, indicating heavy tails and potential outliers in the distribution.
#
# ##### 3. Acceleration (AC) and Deceleration Late (DL):
#
# * Both variables have very low means and medians, indicating that accelerations and late ddecelerations are relatively rare in the dataset.
# * The skewness is positive for DL, indicating a right-skewed distribution, possibly due to a few instances of late decelerations.
# * The kurtosis is higher for DL compared to AC, indicating heavier tails and potentially more extreme values.
#
# ##### 4. Uterine Contractions (UC):
#
# * The mean and median are close, suggesting a relatively symmetric distribution.
# * The skewness is close to zero, indicating a symmetric distribution.
# * The kurtosis is negative, indicating a flatter distribution compared to a normal distribution.
#
# ##### 5. ASTV (Percentage of Time with Abnormal Short Term Variability) and ALTV (Percentage of Time with Abnormal Long Term Variability):
#
# * Both variables have relatively high means and medians, indicating a significant percentage of time with abnormal variability.
# * The distributions are positively skewed, indicating that most observations have lower percentages of abnormal variability, but a few have very high percentages.

# %%
# Histograms
plt.figure(figsize=(12, 8))
for i, col in enumerate(df.columns):
    plt.subplot(3, 5, i+1)
    sns.histplot(df[col], bins=20, kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Boxplots
plt.figure(figsize=(12, 8))
for i, col in enumerate(df.columns):
    plt.subplot(3, 5, i+1)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Scatter plots for pairs of variables
sns.pairplot(df[['LB', 'AC', 'FM', 'UC', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'NSP']])
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Violin plots for selected variables
plt.figure(figsize=(12, 8))
for i, col in enumerate(['LB', 'AC', 'FM', 'UC', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'NSP']):
    plt.subplot(2, 5, i+1)
    sns.violinplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion:
#
# #### Correlations between Variables:
#
# ##### 1. Baseline Fetal Heart Rate (LB) and Percentage of Time with Abnormal Short Term Variability (ASTV):
# * Tere is a moederate positive correlation (0.31) between LB and ASTV. This suggests that as the baseline fetal heart rate increases, the percentage of time with abnormal shor-term variability also tends to increase.
#
# * Implication: Higher baseline fetal heart rates might be associated with increased risk or incidence of abnormal short-term variability, which could be indicative of fetal distress or other health issues.
#
# ##### 2. Mean Value of Short Term Variability (MSTV) and Mean Value of Long Term Variability (MLTV):
# * There is a strong negative correlation (-0.48) between MSTV and MLTV. This indicates that higher values of short-term variability are associated with lower values of long-term variability, and vice versa.
#
# * Implication: This negative correlation suggests a balance between short-term and long-term variability in fetal heart rate patterns. Deviations from this balance might indicate abnormal fetal development or distress.
#
# ##### 3. Width and Accelerations (AC):
# * There is a moderate positive correlation (0.30) between width and AC. This suggests that higher width values are associated with more accelerations in fetal heart rate.
#
# * Implication: Width might be indicative of certain physiological conditions or stages of pregnancy that lead to more frequent accelerations in feta heart rate.
#
# #### Trends or Patterns Over Time:
#
# Since the dataset does not explicitly contain temporal data such as dates or timestamps, we cannot analyze trends over time directly. However, if the dataset includes sequential observations for each patient for example measurements taken at different stages of pregnancy, we can still analyse trends by considering the sequence of abservations for each individual.

# %% [markdown]
# ## Report:
#
# ### Key Insights and Patterns Discovered:
#
# 1. Baseline Fetal Heart Rate (LB):
#
# * Shows a relatively symmetric distribution with a moderate variability.
# * Mean and Median are close, indicating a central tendency around 133 bpm.
# * Negative Kurtosis suggests a slightly flatter distribution than normal.
#
# 2. Fetal Movement (FM):
#
# * Highly skewed distribution with most observations having no fetal movements detected.
# * Extremely high kurtosis indicates heavy tails and potential outliers.
#
# 3. Acceleration (AC) and Deceleration Late (DL):
#
# * Both variables are rare in the dataset, with low means and medians.
# * Positive skewness for DL suggests a right-skewed distribution with potentially extreme values.
#
# 4. Uterine Contractions (UC):
#
# * Relatively symmetric distribution with a moderate variability.
# * Negative kurtosis indicates a flatter distribution compared to normal.
#
# 5. ASTV and ALTV:
#
# * Both variables show a significant percentage of time with abnormal variability.
# * Positively skewed distributions suggest most observations have lower percentages of abnormal variability, with some extreme values.
#
# ### Impact and Further Analysis:
#
# 1. Clinical Decision-Making:
#
# * Understanding correlations between variables like LB and ASTV can help clinicians assess fetal well-being and potentially predict fetal distress.
# * Monitoring trends in FM or variability measures over time can aid in early detection of abnormalities and prompt intervention.
#
# 2. Further Analysis:
#
# * Investigate outliers and extreme values to determine if they represent valid physiological variations or errors in mearsurement.
# * Explore additional variables or interactions between variables to uncover deeper insights into fetal health indicators.
#
# 3. Longitudinal Studies:
#
# * If temporal data becomes available, conducting longitudinal studies to track changes in fetal parameters throughout pregnancy can provide valuable insights into fetal development and health outcomes.
#
# 4. Model Development:
#
# * Use the insights gained from exploratory analysis to develop predictive models for fetal distress or other adverse outcomes.
# * Incorporate additional clinical data or features to improve model performance and accuracy.
